# %%
# Paquetes a instalar
# !pip install PyDrive

# %%
# Librerias a utilizar
import pandas as pd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Abro el archivo 'linktitle'
id='1d3DX6cxtkPw-3en3xG_SakTw7y8UeVBK'
downloaded=drive.CreateFile({'id':id}) 
downloaded.GetContentFile('linktitle.csv')  
dflink=pd.read_csv('linktitle.csv')
#dftit=dftit[dftit['link']!='/']
#dflink=dflink.drop(['Unnamed: 0'], axis=1)

# %%
# Librerias a utilizar
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Abro el archivo 'body69k'
id='1lRCKm4Gu2nMdxf8iaapkFJtFbjKEtVER'
downloaded=drive.CreateFile({'id':id}) 
downloaded.GetContentFile('body69k.csv')  
dfbody69k=pd.read_csv('body69k.csv')
dfbody69k.body=dfbody69k.body.astype(str)
#dftit=dftit[dftit['link']!='/']
#dflink=dflink.drop(['Unnamed: 0'], axis=1)

# %%
dfbody69k.head()
# Out:
#    Unnamed: 0                                               body
# 0           0  El Gobierno anunció que extenderá una semana m...
# 1           1  Cuando comenzó la cuarentena por coronavirus, ...
# 2           2  Para el economista José Luis Espert"este es un...
# 3           3  El gobierno de Alberto Fernández intervinó la ...
# 4           4  Preocupados por la fuerte caída en la producci...

# %%
dflink.head()
len(dflink)
# Out:
# 69930

# %%
# Armo dataframe link+titulos+cuerpo
l=len(dfbody69k)
dflinkbody=dflink[0:l]
dflinkbody=pd.concat([dflinkbody,dfbody69k], axis=1)
dflinkbody=dflinkbody.drop(['Unnamed: 0'], axis=1)
dflinkbody

# %%
import nltk
nltk.download('stopwords')
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import spacy
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from pathlib import Path
#fileContent = Path(url).read_text()
stpwd_es=list(set(stopwords.words('spanish'))) ##### DEFINO UN DICCIONARIO DE STOP WORDS

# Abro el archivo 'stpwd_v1.txt'
id='1BeMeA3GQma9Femlj-2psxinv0B6wgvav'
downloaded=drive.CreateFile({'id':id}) 
downloaded.GetContentFile('stpwd_v1.txt')
f=open("stpwd_v1.txt", "r")
stpwdv1=list()
with f as f:
  for line in f:
    stpwdv1.append(line)
  stpwdv1=[line.rstrip('\n') for line in stpwdv1]

# %%
import re

def norm_text(text):
  text = text.lower()  
  # remove punctuation that is not word-internal (e.g., hyphens, apostrophes)
  text=re.sub('\s\W',' ',text)
  text=re.sub('\W\s',' ',text)
  text = text.replace('"', " ")
  # elimino palabras con 2 letras
  text=re.sub(r'\W*\b\w{1,2}\b', '',text)
  # elimino los espacios dobles
  text=re.sub('\s+',' ',text)
  return text

# %%
#no correr a menos que sea necesario
#retoques a los titulos
dflinkbody['tit_stpwd']=[norm_text(text) for text in dflinkbody['titulo']]
dflinkbody['tit_stpwd']=dflinkbody['tit_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwd_es))
dflinkbody['tit_stpwd']=dflinkbody['tit_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwdv1))
#retoques a los cuerpos de las notas
dflinkbody['cuerpo_stpwd']=[norm_text(text) for text in dflinkbody['body']]
dflinkbody['cuerpo_stpwd']=dflinkbody['cuerpo_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwd_es))
dflinkbody['cuerpo_stpwd']=dflinkbody['cuerpo_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwdv1))

# %%
from google.colab import drive
drive.mount('drive')
dflinkbody.to_csv('linkbody.csv')
# !cp linkbody.csv '/content/drive/My Drive/PROGRAMACION/TRABAJO FINAL/Maxi'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
# Librerias a utilizar
import pandas as pd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

id='1kiku_5j_-Hko1zvitsUZFF7-Xziz2Ufd'
downloaded=drive.CreateFile({'id':id}) 
downloaded.GetContentFile('linkbody.csv')  
dflinkbody=pd.read_csv('linkbody.csv')
dflinkbody['cuerpo_stpwd']=dflinkbody['cuerpo_stpwd'].astype(str)
#dftit=dftit[dftit['link']!='/']
dflinkbody=dflinkbody.drop(['Unnamed: 0'], axis=1)
dflinkbody
# Out:
#                                                     link  ...                                       cuerpo_stpwd
# 0      http://www.lanacion.com.ar/2378370-deuda-el-go...  ...  gobierno anunció extenderá semana junio renego...
# 1      http://www.lanacion.com.ar/2377007-como-es-eco...  ...  comenzó cuarentena coronavirus decenas activid...
# 2      http://www.lanacion.com.ar/2378189-jose-luis-e...  ...  economista josé luis espert gobierno payasos a...
# 3      http://www.lanacion.com.ar/2378169-la-respuest...  ...  gobierno alberto fernández intervinó empresa v...
# 4      http://www.lanacion.com.ar/2377806-vaca-muerta...  ...  preocupados fuerte caída producción gas deriva...
# ...                                                  ...  ...                                                ...
# 69925  http://www.lanacion.com.ar/2348783-lionel-mess...  ...  controversia dando vuelta barcelona intención ...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

# %%
# pull the data into vectors
vectorizer = CountVectorizer()
x = vectorizer.fit_transform(dflinkbody['cuerpo_stpwd'])

encoder = LabelEncoder()
y = encoder.fit_transform(dflinkbody['categoria'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# take a look at the shape of each of these
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (48951, 319247)
# (48951,)
# (20979, 319247)
# (20979,)

# %%
nb = MultinomialNB()
nb.fit(x_train, y_train)
print(nb.score(x_test, y_test))
# Out:
# 0.8762095428762096

# %%
x_test_pred = nb.predict(x_test)
confusion_matrix(y_test, x_test_pred)
# Out:
# array([[2652,    8,   19,  128,   93,   67,   52],
#        [  36, 2785,    4,   24,   26,   36,   24],
#        [  52,    7, 2628,   12,  162,   94,   22],
#        [  89,   11,    0, 2811,   18,   31,    4],
#        [  77,    9,  174,   16, 2592,  130,    2],
#        [ 204,   38,   92,  121,  143, 2334,  128],
#        [ 287,   22,   58,   44,    4,   29, 2580]])

# %%
print(classification_report(y_test, x_test_pred, target_names=encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#      cultura       0.78      0.88      0.83      3019
#     deportes       0.97      0.95      0.96      2935
#     economia       0.88      0.88      0.88      2977
#   personajes       0.89      0.95      0.92      2964
#     politica       0.85      0.86      0.86      3000
#     sociedad       0.86      0.76      0.81      3060
#      turismo       0.92      0.85      0.88      3024
#
#     accuracy                           0.88     20979
#    macro avg       0.88      0.88      0.88     20979
# weighted avg       0.88      0.88      0.88     20979

# %%
def make_reverse_vocabulary(vectorizer):
    revvoc = {}

    vocab = vectorizer.vocabulary_
    for w in vocab:
        i = vocab[w]

        revvoc[i] = w

    return revvoc

make_reverse_vocabulary(vectorizer)
# Out:
# {144394: 'gobierno',
#  30084: 'anunció',
#  127693: 'extenderá',
#  270978: 'semana',
#  172621: 'junio',
#  255148: 'renegociación',
#  101136: 'deuda',
#  52253: 'bonistas',
#  301560: 'títulos',
#  181696: 'legislación',
#  128078: 'extranjera',
#  229245: 'pese',
#  121874: 'esperaba',
#  116691: 'enmienda',
#  216500: 'oferta',
#  219111: 'original',
#  239382: 'principio',
#  138276: 'funcionario',
#  109605: 'economía',
#  54198: 'brecha',
#  26588: 'amplia',
#  90304: 'dato',
#  72412: 'clave',
#  104006: 'diseño',
#  311258: 'vri',
#  305097: 'value',
#  250677: 'recovery',
#  165207: 'instrument',
#  15270: 'achicar',
#  312174: 'warrant',
#  52288: 'bono',
#  37483: 'atado',
#  127262: 'exportaciones',
#  305513: 'variable',
#  140010: 'ganaba',
#  62989: 'carrera',
#  20238: 'agregaba',
#  203210: 'modificaba',
#  88885: 'cálculos',
#  216580: 'oficiales',
#  286102: 'sustentabilidad',
#  39193: 'aumento',
#  306713: 'ventas',
#  127760: 'exterior',
# ...

# %%
voc_freq=make_reverse_vocabulary(vectorizer)
voc_freq=pd.DataFrame(voc_freq.items())
voc_freq.columns=['freq','word'] 
voc_freq=voc_freq.sort_values('freq',ascending=False)
#voc_freq.to_csv('/content/drive/My Drive/PROGRAMACION/TRABAJO FINAL/Maxi/voc_freq.csv')
voc_freq
# Out:
#           freq             word
# 261901  319246            žižek
# 280832  319245              ćak
# 209265  319244  þorsteinsdóttir
# 89732   319243       þingvellir
# 95981   319242            þeudo
# ...        ...              ...
# 283056       4            00011
# 257343       3             0001
# 227562       2            00000
# 73108        1             0000
# 130          0              000
#
# [319247 rows x 2 columns]

# %%
dflinkbody['cuerpo_stpwd'][dflinkbody['cuerpo_stpwd'].str.contains("žižek")]
# Out:
# 46014    vale pena comenzar digresión tierra extraños h...
# Name: cuerpo_stpwd, dtype: object

# %%
def predict_cat(title):
    cod=nb.predict(vectorizer.transform([title]))
    return encoder.inverse_transform(cod)[0]

# %%
# Clasifico noticias de otros diarios
import matplotlib.pyplot as plt
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

#Links que funcionan:"https://cronista.com/","https://ambito.com/","https://iprofesional.com/"

#Links que NO funcionan:
#"https://lanacion.com.ar/","https://página12.com.ar"

#Rellenar lista con diarios de interés:
diarios=['https://www.cronista.com/']#, 'https://www.infobae.com/']
#,"https://ambito.com/","https://iprofesional.com/"]

link=[]
tit=[]
source=[]
cat=[]

for d in diarios:
  with urlopen(d) as response:
    soup=BeautifulSoup(response, 'html.parser')
    for links in soup.find_all('a', href=True, title=True, class_=False, attrs={'target': re.compile('_self')}):  
      source.append(d)
      link.append(links.get('href'))
      if links.get('title')=='':
        tit.append(links.text),
      else:
        tit.append(links.get('title'))
 
dic={'link':link, 'titulo':tit, 'fuente': source}
news=pd.DataFrame(dic)
news['titulo']=[item.translate(str.maketrans('','','\t\n')) for item in news['titulo']]
news.drop_duplicates(subset='link', keep='first', inplace=True)
news.reset_index(drop=True, inplace=True)

from google.colab import drive
drive.mount('drive')
news.to_csv('news.csv')
# !cp news.csv '/content/drive/My Drive/PROGRAMACION/TRABAJO FINAL/Maxi'

news

# %%
news_body=[]
link_body=[]

for l in news['link']:
  try:
    with urlopen('https://www.cronista.com'+l) as response:
      soup=BeautifulSoup(response, 'html.parser')
      p=soup.find_all('p')
      text=[tag.get_text().strip() for tag in p]
      text=[sentence for sentence in text if sentence.endswith('.')]
      #text=[sentence for sentence in text if not sentence.startswith('A través de este formulario')]
      #text=[sentence for sentence in text if not sentence.startswith('Para continuar con tu lectura')]
      #text=[sentence for sentence in text if not sentence.startswith('Anotate y recibí')]
      #text=[sentence for sentence in text if not sentence.startswith('Estas reportando este comentario')]
      #text=[sentence for sentence in text if not sentence.startswith('He leído y acepto')]
      text=[sentence.replace('\r\n\r\n', '') for sentence in text]
      text=[sentence.replace('\n', '') for sentence in text]
      text=[sentence.replace('\r', ' ') for sentence in text]
      text=[sentence.replace('\xa0', ' ') for sentence in text]
      text=' '.join(text)
      news_body.append(text)
      link_body.append (l)
  except:
    news_body.append(0)
    link_body.append (l)
    pass

dic={'link':link_body, 'cuerpo':news_body}
news_body=pd.DataFrame(dic)

#news_body=[row for row in news_body if row!='']

from google.colab import drive
drive.mount('drive')
news_body.to_csv('news_body.csv')
# !cp news_body.csv '/content/drive/My Drive/PROGRAMACION/TRABAJO FINAL/Maxi'

news_body

# %%
#news_body
#print(len(news_body),len(news))
news_body=pd.merge(news, news_body, on='link')
news_body

# %%
#news_body['cuerpo']=news_body['cuerpo'].astype(str)
news_body['cuerpo_stpwd']=[norm_text(text) for text in news_body['cuerpo']]
news_body['cuerpo_stpwd']=news_body['cuerpo_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwd_es))
news_body['cuerpo_stpwd']=news_body['cuerpo_stpwd'].apply(lambda x: " ".join(x for x in x.split() if x not in stpwdv1))
news_body['categoria']=[predict_cat(cuerpo) for cuerpo in news_body['cuerpo_stpwd']]
news_body

# %%
from google.colab import drive
drive.mount('drive')
news_body.to_csv('news_body_predict.csv')
# !cp news_body_predict.csv '/content/drive/My Drive/PROGRAMACION/TRABAJO FINAL/Maxi'

news_body

# %%
#!pip install newspaper3k
#nltk.download('punkt')

from newspaper import Article
url='https://www.lanacion.com.ar/sociedad/coronavirus-argentina-nid2387898'
url1='https://www.cronista.com/economiapolitica/Empresas-desregulan-el-pago-de-aguinaldos-y-se-cruzan-con-gremios-20200629-0056.html'
#with urlopen('https://www.cronista.com'+l) as response:
article=Article(url)
article.download()
article.html
article.parse()
#article.authors
#article.publish_date
#article.text
article.nlp()
#article.keywords
article.summary
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 'Se confirmaron 2335 nuevos contagios de coronavirus en el país Fuente: LA NACION - Crédito: Daniel JayoComentar Me gusta Me gusta Compartir E-mail Twitter Facebook WhatsApp Guardar 29 de junio de 2020 • 19:47El Gobierno informó 2335 nuevos casos de coronavirus Covid-19 en las últimas 24 horas en el país y ya son 62.268 los infectados.\nEn tanto, se sumaron 48 muertes y el total de fallecidos es de 1280.\nLa de hoy es la cifra más alta de decesos en un día desde que comenzó la crisis.\nTres de ellas, de 60, 38 y 94 años, eran de Buenos Aires; cinco, de 71, 89, 96, 84 y 47 años, residentes en la ciudad de Buenos Aires; una de 71 años de Neuquén; y una de 61 años de Chaco.\nEscándalo y renunciasLas consecuencias de los partidos de pádel en plena cuarentena en un club de Pilar continúan.'

# %%
# !pip install selenium

from selenium import webdriver

DRIVER_PATH = 'C:/Users/maxim/chromedriver.exe'
#driver = webdriver.Chrome(executable_path=DRIVER_PATH)

options = webdriver.ChromeOptions()
options.add_argument('user-agent = Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36')
driver = webdriver.Chrome(chrome_options=options, executable_path=DRIVER_PATH)

driver.get('https://google.com')
# Out:
# ...
#      |████████████████████████████████| 911kB 6.0MB/s
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: use options instead of chrome_options
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# ...
